# %% [markdown]
# # DSTI ML Project A22 Cohort: Book Rating Predictor
# The aim of the project is to train and evaluate different models that predict a book’s rating from a GoodReads dataset

# %%
# Ensure to select the .venv-book kernel before importing
# Kernel > Change kernel > .venv-book

import os
import pickle
import pandas as pd
import numpy as np

from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, LassoLars, ElasticNet, Ridge

# %% [markdown]
# ## 3) Model Selection

# %% [markdown]
# ### 3.1) Variation of Feature Sets

# %%
df_prepro = pd.read_csv("../data/books_preprocessed.csv", on_bad_lines='skip')
# As seen previously, in all case we will drop the following columns
print(f"Dataset contains: {df_prepro.shape[0]} rows and {df_prepro.shape[1]} columns")

corr = abs(df_prepro.corr())
corr2 = pd.DataFrame(corr.iloc[1:-1, 0])
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# Dataset contains: 11121 rows and 18 columns
# <style type="text/css">
# #T_0bf22_row0_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_0bf22_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_0bf22_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_0bf22_row3_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_0bf22_row4_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_0bf22_row5_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_0bf22_row6_col0, #T_0bf22_row10_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_0bf22_row7_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_0bf22_row8_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_0bf22_row9_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_0bf22_row11_col0 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_0bf22_row12_col0 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_0bf22_row13_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_0bf22_row14_col0 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_0bf22_row15_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0bf22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0bf22_level0_col0" class="col_heading level0 col0" >average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0bf22_level0_row0" class="row_heading level0 row0" >bookID</th>
#       <td id="T_0bf22_row0_col0" class="data row0 col0" >0.036259</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row1" class="row_heading level0 row1" >isbn13</th>
#       <td id="T_0bf22_row1_col0" class="data row1 col0" >0.001967</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row2" class="row_heading level0 row2" >num_pages</th>
#       <td id="T_0bf22_row2_col0" class="data row2 col0" >0.150430</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row3" class="row_heading level0 row3" >num_pages_p_10</th>
#       <td id="T_0bf22_row3_col0" class="data row3 col0" >0.103904</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row4" class="row_heading level0 row4" >ratings_count</th>
#       <td id="T_0bf22_row4_col0" class="data row4 col0" >0.038228</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row5" class="row_heading level0 row5" >ratings_count_p_10</th>
#       <td id="T_0bf22_row5_col0" class="data row5 col0" >0.115798</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row6" class="row_heading level0 row6" >text_reviews_count</th>
#       <td id="T_0bf22_row6_col0" class="data row6 col0" >0.033669</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row7" class="row_heading level0 row7" >text_reviews_count_p_10</th>
#       <td id="T_0bf22_row7_col0" class="data row7 col0" >0.069308</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row8" class="row_heading level0 row8" >publication_date</th>
#       <td id="T_0bf22_row8_col0" class="data row8 col0" >0.030897</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row9" class="row_heading level0 row9" >publication_year</th>
#       <td id="T_0bf22_row9_col0" class="data row9 col0" >0.031730</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row10" class="row_heading level0 row10" >language_code</th>
#       <td id="T_0bf22_row10_col0" class="data row10 col0" >0.033717</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row11" class="row_heading level0 row11" >title</th>
#       <td id="T_0bf22_row11_col0" class="data row11 col0" >0.026518</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row12" class="row_heading level0 row12" >title_len</th>
#       <td id="T_0bf22_row12_col0" class="data row12 col0" >0.096451</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row13" class="row_heading level0 row13" >author_1</th>
#       <td id="T_0bf22_row13_col0" class="data row13 col0" >0.021646</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row14" class="row_heading level0 row14" >author_2</th>
#       <td id="T_0bf22_row14_col0" class="data row14 col0" >0.051174</td>
#     </tr>
#     <tr>
#       <th id="T_0bf22_level0_row15" class="row_heading level0 row15" >num_authors</th>
#       <td id="T_0bf22_row15_col0" class="data row15 col0" >0.018947</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# According to the above table
# - ```num_pages```
# - ```ratings_count_p_10```
# - ```title_len```
# - ```text_reviews_count_p_10```
# - ```author_2```
#
# have the highest correlation with the target.
#
# However for the "engineered" features, we have lost some information about the dataset, hence higher correlation with the target will not necessarily translate into producing a better model, thats why we will have this experimental approach.

# %%
df1 = df_prepro.drop(columns=["isbn13", "num_authors", "title", "publication_year"])
df2 = df_prepro.drop(columns=["isbn13", "num_authors", "title", "publication_year", "bookID"])
df3 = df_prepro.drop(columns=["isbn13", "num_authors", "title", "publication_year", "bookID", "ratings_count_p_10"])
df4 = df_prepro.drop(columns=["isbn13", "num_authors", "title", "publication_year", "bookID", "ratings_count_p_10", "text_reviews_count_p_10"])
df5 = df_prepro.drop(columns=["isbn13", "num_authors", "title", "publication_year", "bookID", "ratings_count_p_10", "text_reviews_count_p_10", "title_len"])

df_list = [df1, df2, df3, df4, df5]

# %% [markdown]
# ### 3.2) Data split

# %%
def data_split(
    df: pd.DataFrame, 
    targets: str, 
    test_size: float = 0.2, 
    scaler = None
) -> tuple:
    features = []
    for var in df.columns:
        if var != targets:
            features.append(var)

    x, y = df[features], df[targets]
    if scaler:
        x = scaler.fit_transform(x)
    # split 80% of the data to the training set and 20% of the data to test set 
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=999)

    return x_train, x_test, y_train, y_test

# %% [markdown]
# ### 3.3) Model Training & Evaluation
#
# Because we are trying to predict a quantity (```average_rating```), our problem is a **Regression** problem, hence we will apply the different regression models from the sklearn package and compare the performance. The models will be:
# - LinearRegression (Linear)
# - LassoLars (Linear)
# - ElasticNet (Linear)
# - Ridge (Linear)
# - RandomForestRegressor (Ensemble)
# - SVR linear or rbf (SVM)
#
# For evaluation we will use the following metrics:
# - Mean Absolute Error (MAE): We want to **minimize**
# - Root Mean Square Error (RMSE): We want to **minimize**
# - R2: We want to **maximize**
#
# <u>Note</u>:
# - *MAE* and *RMSE* measure how accurate the predictions are according to the ground truth
# - *R2* measures how much of the features variation is explained by the target in the model.

# %%
def model_comparator(train_test_data: tuple, models_dict: dict) -> pd.DataFrame:
    eval_table = {}
    models = {}
    x_train, x_test = train_test_data[0], train_test_data[1]
    y_train, y_test = train_test_data[2], train_test_data[3]
    
    for model_name, model in models_dict.items():
        model.fit(x_train, y_train)
        models[model_name] = model
        predictions = model.predict(x_test)

        mae = metrics.mean_absolute_error(y_test, predictions)
        rmse = np.sqrt(metrics.mean_squared_error(y_test, predictions))
        r2 = metrics.r2_score(y_test, predictions)

        eval_table[model_name] = [mae, rmse, r2]
    
    eval_df = pd.DataFrame.from_dict(eval_table, orient="index", columns=["MAE (min)", "RMSE (min)", "R2 (max)"])
    
    return models, eval_df

# %%
# Define models
regression_models = {
    "LinearRegression": LinearRegression(),
    "LassoLars": LassoLars(alpha=0.8),
    "ElasticNet": ElasticNet(alpha=0.8),
    "Ridge": Ridge(alpha=0.5),
    "RandomForest": RandomForestRegressor(),
    "SVR_rbf": SVR(kernel="rbf"),
    # "SVR_linear": SVR(kernel="linear"), # /!\ Takes too long to fit   
}
# Setup random seed
np.random.seed(42)
# Split data
train_test_data = data_split(df=df_prepro, targets="average_rating", test_size=0.2, scaler=StandardScaler())
# Train & evaluate models
trained_models, eval_df = model_comparator(train_test_data, regression_models)
# Apply heatmap for EACH column 
eval_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_66358_row0_col0 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_66358_row0_col1, #T_66358_row3_col1 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_66358_row0_col2, #T_66358_row3_col2 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_66358_row1_col0, #T_66358_row1_col1, #T_66358_row2_col0, #T_66358_row2_col1, #T_66358_row4_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_66358_row1_col2, #T_66358_row2_col2, #T_66358_row4_col0, #T_66358_row4_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_66358_row3_col0 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_66358_row5_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_66358_row5_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_66358_row5_col2 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# </style>
# <table id="T_66358">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_66358_level0_col0" class="col_heading level0 col0" >MAE (min)</th>
#       <th id="T_66358_level0_col1" class="col_heading level0 col1" >RMSE (min)</th>
#       <th id="T_66358_level0_col2" class="col_heading level0 col2" >R2 (max)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66358_level0_row0" class="row_heading level0 row0" >LinearRegression</th>
#       <td id="T_66358_row0_col0" class="data row0 col0" >0.232033</td>
#       <td id="T_66358_row0_col1" class="data row0 col1" >0.387602</td>
#       <td id="T_66358_row0_col2" class="data row0 col2" >0.063756</td>
#     </tr>
#     <tr>
#       <th id="T_66358_level0_row1" class="row_heading level0 row1" >LassoLars</th>
#       <td id="T_66358_row1_col0" class="data row1 col0" >0.244431</td>
#       <td id="T_66358_row1_col1" class="data row1 col1" >0.401092</td>
#       <td id="T_66358_row1_col2" class="data row1 col2" >-0.002549</td>
#     </tr>
#     <tr>
#       <th id="T_66358_level0_row2" class="row_heading level0 row2" >ElasticNet</th>
#       <td id="T_66358_row2_col0" class="data row2 col0" >0.244431</td>
#       <td id="T_66358_row2_col1" class="data row2 col1" >0.401092</td>
#       <td id="T_66358_row2_col2" class="data row2 col2" >-0.002549</td>
#     </tr>
#     <tr>
#       <th id="T_66358_level0_row3" class="row_heading level0 row3" >Ridge</th>
#       <td id="T_66358_row3_col0" class="data row3 col0" >0.232020</td>
#       <td id="T_66358_row3_col1" class="data row3 col1" >0.387612</td>
#       <td id="T_66358_row3_col2" class="data row3 col2" >0.063705</td>
#     </tr>
#     <tr>
#       <th id="T_66358_level0_row4" class="row_heading level0 row4" >RandomForest</th>
#       <td id="T_66358_row4_col0" class="data row4 col0" >0.217063</td>
#       <td id="T_66358_row4_col1" class="data row4 col1" >0.362639</td>
#       <td id="T_66358_row4_col2" class="data row4 col2" >0.180465</td>
#     </tr>
#     <tr>
#       <th id="T_66358_level0_row5" class="row_heading level0 row5" >SVR_rbf</th>
#       <td id="T_66358_row5_col0" class="data row5 col0" >0.223324</td>
#       <td id="T_66358_row5_col1" class="data row5 col1" >0.378858</td>
#       <td id="T_66358_row5_col2" class="data row5 col2" >0.105518</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We clearly see that the `RandomForestRegressor()` is the best model when training over the full dataset as it produces the minimum *MAE* and *RMSE* and the maximum *R2*.
#
# We will now check, which feature selection gives the best performance.

# %% [markdown]
# ### 3.4) Feature Selection for model

# %%
# Define models
result = pd.DataFrame(columns=["MAE (min)", "RMSE (min)", "R2 (max)"])

for i, df in enumerate(df_list):
    regression_models = {
        f"RandomForest_df{i+1}": RandomForestRegressor(),
    }
    # Setup random seed
    np.random.seed(42)
    # Split data
    train_test_data = data_split(df=df, targets="average_rating", test_size=0.2, scaler=StandardScaler())
    # Train & evaluate models
    trained_model, eval_df = model_comparator(train_test_data, regression_models)
    result = pd.concat([result, eval_df], axis=0)
    result = result.astype(float)
# Apply heatmap for EACH column 
result.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_2046e_row0_col0, #T_2046e_row2_col1, #T_2046e_row4_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2046e_row0_col1 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_2046e_row0_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_2046e_row1_col0 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_2046e_row1_col1 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_2046e_row1_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_2046e_row2_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_2046e_row2_col2, #T_2046e_row4_col0, #T_2046e_row4_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2046e_row3_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_2046e_row3_col1 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_2046e_row3_col2 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2046e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2046e_level0_col0" class="col_heading level0 col0" >MAE (min)</th>
#       <th id="T_2046e_level0_col1" class="col_heading level0 col1" >RMSE (min)</th>
#       <th id="T_2046e_level0_col2" class="col_heading level0 col2" >R2 (max)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2046e_level0_row0" class="row_heading level0 row0" >RandomForest_df1</th>
#       <td id="T_2046e_row0_col0" class="data row0 col0" >0.217028</td>
#       <td id="T_2046e_row0_col1" class="data row0 col1" >0.358669</td>
#       <td id="T_2046e_row0_col2" class="data row0 col2" >0.198312</td>
#     </tr>
#     <tr>
#       <th id="T_2046e_level0_row1" class="row_heading level0 row1" >RandomForest_df2</th>
#       <td id="T_2046e_row1_col0" class="data row1 col0" >0.218908</td>
#       <td id="T_2046e_row1_col1" class="data row1 col1" >0.356993</td>
#       <td id="T_2046e_row1_col2" class="data row1 col2" >0.205788</td>
#     </tr>
#     <tr>
#       <th id="T_2046e_level0_row2" class="row_heading level0 row2" >RandomForest_df3</th>
#       <td id="T_2046e_row2_col0" class="data row2 col0" >0.218598</td>
#       <td id="T_2046e_row2_col1" class="data row2 col1" >0.354323</td>
#       <td id="T_2046e_row2_col2" class="data row2 col2" >0.217625</td>
#     </tr>
#     <tr>
#       <th id="T_2046e_level0_row3" class="row_heading level0 row3" >RandomForest_df4</th>
#       <td id="T_2046e_row3_col0" class="data row3 col0" >0.218591</td>
#       <td id="T_2046e_row3_col1" class="data row3 col1" >0.355697</td>
#       <td id="T_2046e_row3_col2" class="data row3 col2" >0.211545</td>
#     </tr>
#     <tr>
#       <th id="T_2046e_level0_row4" class="row_heading level0 row4" >RandomForest_df5</th>
#       <td id="T_2046e_row4_col0" class="data row4 col0" >0.225199</td>
#       <td id="T_2046e_row4_col1" class="data row4 col1" >0.363350</td>
#       <td id="T_2046e_row4_col2" class="data row4 col2" >0.177248</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that the **dataset_3** gives the best performance.
#
# Up to now we have used the default parameters of the ```RandomForestRegressor()``` with ```n_estimators``` = 100.
#
# We will try to vary this parameter to increase the performance in the following using dataset_3:

# %% [markdown]
# ### 3.5) Model Finetuning

# %%
# /!\ The cell takes about 8 mins to run
# Define models
regression_models = {
    'RandomForest_50': RandomForestRegressor(n_estimators=50),
    'RandomForest_100': RandomForestRegressor(n_estimators=100),
    'RandomForest_500': RandomForestRegressor(n_estimators=500),
    'RandomForest_1000': RandomForestRegressor(n_estimators=1000),
}
# Setup random seed
np.random.seed(42)
# Split data
train_test_data = data_split(df=df3, targets="average_rating", test_size=0.2, scaler=StandardScaler())
# Train & evaluate models
trained_models, eval_df = model_comparator(train_test_data, regression_models)

# Apply heatmap for EACH column 
eval_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_8685d_row0_col0 {
#   background-color: #cd423b;
#   color: #f1f1f1;
# }
# #T_8685d_row0_col1, #T_8685d_row1_col0, #T_8685d_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8685d_row0_col2, #T_8685d_row1_col1, #T_8685d_row3_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_8685d_row2_col0 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_8685d_row2_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_8685d_row2_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_8685d_row3_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_8685d_row3_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# </style>
# <table id="T_8685d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8685d_level0_col0" class="col_heading level0 col0" >MAE (min)</th>
#       <th id="T_8685d_level0_col1" class="col_heading level0 col1" >RMSE (min)</th>
#       <th id="T_8685d_level0_col2" class="col_heading level0 col2" >R2 (max)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8685d_level0_row0" class="row_heading level0 row0" >RandomForest_50</th>
#       <td id="T_8685d_row0_col0" class="data row0 col0" >0.219300</td>
#       <td id="T_8685d_row0_col1" class="data row0 col1" >0.358550</td>
#       <td id="T_8685d_row0_col2" class="data row0 col2" >0.198844</td>
#     </tr>
#     <tr>
#       <th id="T_8685d_level0_row1" class="row_heading level0 row1" >RandomForest_100</th>
#       <td id="T_8685d_row1_col0" class="data row1 col0" >0.219362</td>
#       <td id="T_8685d_row1_col1" class="data row1 col1" >0.352650</td>
#       <td id="T_8685d_row1_col2" class="data row1 col2" >0.224994</td>
#     </tr>
#     <tr>
#       <th id="T_8685d_level0_row2" class="row_heading level0 row2" >RandomForest_500</th>
#       <td id="T_8685d_row2_col0" class="data row2 col0" >0.218663</td>
#       <td id="T_8685d_row2_col1" class="data row2 col1" >0.354661</td>
#       <td id="T_8685d_row2_col2" class="data row2 col2" >0.216127</td>
#     </tr>
#     <tr>
#       <th id="T_8685d_level0_row3" class="row_heading level0 row3" >RandomForest_1000</th>
#       <td id="T_8685d_row3_col0" class="data row3 col0" >0.218490</td>
#       <td id="T_8685d_row3_col1" class="data row3 col1" >0.355925</td>
#       <td id="T_8685d_row3_col2" class="data row3 col2" >0.210531</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can see that both models with ```n_estimators``` = 100 and 500 have the best balanced performances. Hence we will save them.

# %%
# Save the model to disk
modelpkl = '../models/book_ratings_RDFR_100_df3.pt'
if not os.path.isfile(modelpkl):
    pickle.dump(trained_models["RandomForest_100"], open(modelpkl, 'wb'))

# %% [markdown]
# We can see from the above table that the RandomForest with ```n_estimators``` **100**, **500** and **1000** have the best balanced performance.\
# However, there are other parameters in the RandomForest that can be finetuned to select our final model, and for this we will do a gridsearch.

# %% [markdown]
# ### 3.6) Model Finetuning through GridSearch

# %%
# /!\ 1h30 to run this cell
# Define the search space of parameters
param_grid = {
    'n_estimators': [100, 500, 1000],
    'min_samples_split': [2, 4, 6],
    'min_samples_leaf': [1, 2, 3],
    'bootstrap': [True, False],
}
# Define the grid 
model_grid = GridSearchCV(estimator=RandomForestRegressor(), param_grid=param_grid, cv=3, verbose=2, n_jobs=4)
# Setup random seed
np.random.seed(42)
# Split data
x_train, x_test, y_train, y_test = data_split(df=df3, targets="average_rating", test_size=0.2,  scaler=StandardScaler())
# Fit df3
model_grid.fit(x_train, y_train)
pd.DataFrame.from_dict(model_grid.best_params_, orient="index").T
# Out:
# Fitting 3 folds for each of 54 candidates, totalling 162 fits
#   bootstrap min_samples_leaf min_samples_split n_estimators
# 0      True                3                 6          500

# %%
# Evaluate "Best" Model from GridSearch
predictions = model_grid.predict(x_test)
r2 = metrics.r2_score(y_test, predictions)
mae = metrics.mean_absolute_error(y_test, predictions)
rmse = np.sqrt(metrics.mean_squared_error(y_test, predictions))

best_perf = pd.DataFrame([mae, rmse, r2], index=["MAE (min)", "RMSE (min)", "R2 (max)"], columns=["RandomForest_Grid"]).T

if "RandomForest_Grid" not in eval_df.index:
    eval_df = pd.concat([eval_df, best_perf], axis=0)
# Apply heatmap across EACH column
eval_df.style.background_gradient(cmap='coolwarm',axis=0)
# Out:
# <style type="text/css">
# #T_ce91a_row0_col0 {
#   background-color: #cc403a;
#   color: #f1f1f1;
# }
# #T_ce91a_row0_col1, #T_ce91a_row1_col0, #T_ce91a_row1_col2 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_ce91a_row0_col2, #T_ce91a_row1_col1, #T_ce91a_row4_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_ce91a_row2_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_ce91a_row2_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_ce91a_row2_col2 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_ce91a_row3_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_ce91a_row3_col1 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_ce91a_row3_col2 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_ce91a_row4_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_ce91a_row4_col2 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# </style>
# <table id="T_ce91a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ce91a_level0_col0" class="col_heading level0 col0" >MAE (min)</th>
#       <th id="T_ce91a_level0_col1" class="col_heading level0 col1" >RMSE (min)</th>
#       <th id="T_ce91a_level0_col2" class="col_heading level0 col2" >R2 (max)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce91a_level0_row0" class="row_heading level0 row0" >RandomForest_50</th>
#       <td id="T_ce91a_row0_col0" class="data row0 col0" >0.219300</td>
#       <td id="T_ce91a_row0_col1" class="data row0 col1" >0.358550</td>
#       <td id="T_ce91a_row0_col2" class="data row0 col2" >0.198844</td>
#     </tr>
#     <tr>
#       <th id="T_ce91a_level0_row1" class="row_heading level0 row1" >RandomForest_100</th>
#       <td id="T_ce91a_row1_col0" class="data row1 col0" >0.219362</td>
#       <td id="T_ce91a_row1_col1" class="data row1 col1" >0.352650</td>
#       <td id="T_ce91a_row1_col2" class="data row1 col2" >0.224994</td>
#     </tr>
#     <tr>
#       <th id="T_ce91a_level0_row2" class="row_heading level0 row2" >RandomForest_500</th>
#       <td id="T_ce91a_row2_col0" class="data row2 col0" >0.218663</td>
#       <td id="T_ce91a_row2_col1" class="data row2 col1" >0.354661</td>
#       <td id="T_ce91a_row2_col2" class="data row2 col2" >0.216127</td>
#     </tr>
#     <tr>
#       <th id="T_ce91a_level0_row3" class="row_heading level0 row3" >RandomForest_1000</th>
#       <td id="T_ce91a_row3_col0" class="data row3 col0" >0.218490</td>
#       <td id="T_ce91a_row3_col1" class="data row3 col1" >0.355925</td>
#       <td id="T_ce91a_row3_col2" class="data row3 col2" >0.210531</td>
#     </tr>
#     <tr>
#       <th id="T_ce91a_level0_row4" class="row_heading level0 row4" >RandomForest_Grid</th>
#       <td id="T_ce91a_row4_col0" class="data row4 col0" >0.218436</td>
#       <td id="T_ce91a_row4_col1" class="data row4 col1" >0.355440</td>
#       <td id="T_ce91a_row4_col2" class="data row4 col2" >0.212682</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### 3.6) Conclusion
# - **Model Selection**: We will use a `RandomForestRegressor()` with <u>**default parameters**</u>.
# - **Feature Selection**: We will use `dataset_3` for our model i.e we will <u>keep</u> the following features:
#     - `num_pages`
#     - `num_pages_p_10`
#     - `ratings_count`
#     - `text_reviews_count`
#     - `text_reviews_count_p_10`
#     - `publication_date`
#     - `language_code`
#     - `title_len`
#     - `author_1`
#     - `author_2`
#     - `publisher`

# %% [markdown]
# # DSTI ML Project A22 Cohort: Book Rating Predictor
# The aim of the project is to train and evaluate different models that predict a book’s rating from a GoodReads dataset

# %% [markdown]
# ## 0) Environment and Kernel set up
# ### 0.1) Environment Installation
#
# Before running the notebook, we will create a new kernel from a virtual environment that we will create for the project specifically.\
# We will use:
# - **python** to create a virtual envionment
# - **pip** to install all necessary packages
# - **ipython** to create a kernel from our virtual environment
#
# |  |  |
# | --- | --- |
# | ```venv_path``` | **path-to-project\\.venv-book** |
# | ```kernel_path``` | **%USERPROFILE%\\AppData\\Roaming\\jupyter\\kernels\\.venv-book** |

# %%
# Create virtual environment and jupyter kernel
# !python -m venv ..\.venv-book
# !..\.venv-book\Scripts\pip install -r ..\requirements.txt
# !..\.venv-book\Scripts\ipython kernel install --name ".venv-book" --user
# Out:
# ...
#   Using cached ipykernel-6.25.1-py3-none-any.whl (154 kB)
# ...
#   Using cached numpy-1.25.2-cp39-cp39-win_amd64.whl (15.6 MB)
# ...
#   Using cached pandas-2.0.3-cp39-cp39-win_amd64.whl (10.8 MB)
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...
#   Using cached matplotlib-3.7.2-cp39-cp39-win_amd64.whl (7.5 MB)
# ...
#   Using cached seaborn-0.12.2-py3-none-any.whl (293 kB)
# ...
#   Using cached scikit_learn-1.3.0-cp39-cp39-win_amd64.whl (9.3 MB)
# ...
#   Using cached dvc-3.15.3-py3-none-any.whl (420 kB)
# ...
#   Using cached dvc_gdrive-2.20.0-py3-none-any.whl (11 kB)
# ...
#   Using cached psutil-5.9.5-cp36-abi3-win_amd64.whl (255 kB)
# ...
#   Using cached jupyter_core-5.3.1-py3-none-any.whl (93 kB)
# ...
#   Using cached matplotlib_inline-0.1.6-py3-none-any.whl (9.4 kB)
# ...
#   Using cached ipython-8.14.0-py3-none-any.whl (798 kB)
# ...
#   Using cached comm-0.1.4-py3-none-any.whl (6.6 kB)
# ...
#   Using cached jupyter_client-8.3.0-py3-none-any.whl (103 kB)
# ...
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# ...

# %% [markdown]
# ### 0.2) Kernel and Packages
# **/!\ REFRESH the page** and select the **.venv-book** kernel before the imports
# - Kernel > Change kernel > .venv-book
# - Then run the following cell to import the packages

# %%
import os
import datetime

import dvc.api
import pandas as pd
import numpy as np
from scipy.stats import norm

import matplotlib.pyplot as plt
import matplotlib.ticker as tkr
import seaborn as sns

from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression, LassoLars, ElasticNet, Ridge

# %% [markdown]
# The above packages will be needed to run all the notebooks

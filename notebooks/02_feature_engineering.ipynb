# %% [markdown]
# # DSTI ML Project A22 Cohort: Book Rating Predictor
# The aim of the project is to train and evaluate different models that predict a book’s rating from a GoodReads dataset

# %%
# Ensure to select the .venv-book kernel before importing
# Kernel > Change kernel > .venv-book

import datetime
import pandas as pd
from sklearn import preprocessing

# %% [markdown]
# ## 2) Feature Engineering

# %% [markdown]
# ### 2.1) Preprocessing of dataset
# As seen previously, we will drop the ```isbn``` column.
#
# For the ```title```,  ```authors``` and  ```publisher``` variables we will use **Label Encoding** as they have a large number of "categories". We can note also that the ```title``` and  ```authors``` columns will not have much impact on the target variable due to the very large number of "categories" and hence may not be useful to train the model.
#
# For the ```publication_date``` we will convert the date into a continuous variable by:
# - i) Subtracting all the dates with a reference date
# - ii) Taking only the year
#
# For the ```language_code```, since we have only two dummies, we will convert the original column as a boolean variable instead of doing One-Hot Encoding.
#
# | Variable | Pre-processing | New Features |
# | --- | --- | --- |
# | ```average_rating``` | None |  |
# | ```bookID``` | None |  |
# | ```isbn13``` | None |  |
# | ```isbn``` | Drop |  |
# | ```ratings_count```| Quantile Regrouping | ```ratings_count_p_10```|
# | ```text_reviews_count``` | Quantile Regrouping | ```text_reviews_count_p_10``` |
# | ```num_pages``` | Quantile Regrouping | ```text_reviews_count_p_10``` |
# | ```publication_date``` | Date Transformation | ```publication_year``` |
# | ```language_code``` | Standardization (Boolean) |  |
# | ```publisher``` | Label Encoding |  |
# | ```title``` | Label Encoding | ```title_len``` |
# | ```authors``` | Split authors & Label Encoding | ```author1``` + ```author2``` + ```num_authors``` |

# %%
# Read the original dataset
df = pd.read_csv("../data/books.csv", on_bad_lines='skip')
# Clean the columns name
for col in df.columns:
    df = df.rename(columns = {col: col.strip()})
print(f"Original shape of dataset: {df.shape}")
# Out:
# Original shape of dataset: (11123, 12)

# %% [markdown]
# #### 2.1.1) Dropping ```isbn``` column

# %%
df_isbn_drop = df.drop(["isbn"], axis=1)
df_isbn_drop.shape
# Out:
# (11123, 11)

# %% [markdown]
# #### 2.1.2) Quantile Regrouping

# %%
df_Q = df_isbn_drop.copy()
vars = ["num_pages", "ratings_count", "text_reviews_count"]
p = 10
for var in vars:
    var_Q = pd.qcut(df_Q[var], p, labels=False)
    var_Q = var_Q.rename(f"{var}_p_{p}")
    df_Q = pd.concat([df_Q, var_Q], axis=1)
df_Q.shape
# Out:
# (11123, 14)

# %% [markdown]
# #### 2.1.3) Date Transformation of ```publication_date```

# %%
# Check for valid dates in the dataset
df_date_trans = df_Q.copy()
invalid_date = []
for index, row in df_date_trans.iterrows():
    p_date = df_date_trans.loc[index, "publication_date"]
    try:
        p_date2 = datetime.datetime.strptime(p_date,'%m/%d/%Y').date()
    except Exception as e:
        invalid_date.append([index, p_date, e])

pd.DataFrame(invalid_date, columns=["index", "date", "error"])
# Out:
#    index        date                          error
# 0   8177  11/31/2000  day is out of range for month
# 1  11094   6/31/1982  day is out of range for month

# %%
print(f"Before: {len(df_date_trans)}")
for id in invalid_date:
    df_date_trans = df_date_trans.drop([id[0]])
print(f"After: {len(df_date_trans)}")
# Out:
# Before: 11123
# After: 11121

# %% [markdown]
# We convert the date into a continuous value by:
# - i) Subtracting all date with a reference date
# - ii) Taking only the year

# %%
REF_DATE = datetime.date(2023, 8, 4)
for index, row in df_date_trans.iterrows():
    p_date = df_date_trans.loc[index, "publication_date"]
    p_date2 = datetime.datetime.strptime(p_date,'%m/%d/%Y').date()
    num_days = (REF_DATE - p_date2).days
    df_date_trans.at[index, "publication_date"] = num_days
    df_date_trans.at[index, "publication_year"] = p_date2.year

# Ensure the dates are of numeric type
df_date_trans["publication_date"] = df_date_trans["publication_date"].astype(int)
df_date_trans["publication_year"] = df_date_trans["publication_year"].astype(int)
df_date_trans.shape
# Out:
# (11121, 15)

# %% [markdown]
# #### 2.1.4) Standardization of the ```language_code```
# We regroup values of ```language_code``` into only english (1) and others (0)

# %%
df_2_dummies = df_date_trans.copy()

for index, row in df_2_dummies.iterrows():
    if "en" in row["language_code"]:
        df_2_dummies.loc[index, "language_code"] =  1
    else:
        df_2_dummies.loc[index, "language_code"] = 0

df_2_dummies.shape
# Out:
# (11121, 15)

# %% [markdown]
# #### 2.1.5) Make ```title_len```

# %%
df_len_title = df_2_dummies.copy()
for index, row in df_len_title.iterrows():
    df_len_title.loc[index, "title_len"] = len(row["title"])

df_len_title["title_len"] = df_len_title["title_len"].astype(int)
df_len_title.shape
# Out:
# (11121, 16)

# %% [markdown]
# #### 2.1.6) Split ```authors``` and make ```num_authors```

# %%
df_authors_split = df_len_title.copy()
for index, row in df_authors_split.iterrows():
    authors = row["authors"].split("/")
    df_authors_split.loc[index, "num_authors"] = len(authors)
    for i, author in enumerate(authors[0:2]):
        df_authors_split.loc[index, f"author_{i+1}"] = author

df_authors_split["num_authors"] = df_authors_split["num_authors"].astype(int)
df_authors_split = df_authors_split.drop(columns="authors")
df_authors_split.shape
# Out:
# (11121, 18)

# %% [markdown]
# #### 2.1.7) Label Encoding
# We apply **Label Encoding** to the 3 columns with text "categories":
# - ```title```
# - ```authors```
# - ```author_1```
# - ```author_2```
# - ```publisher```

# %%
df_label_encoded = df_authors_split.copy()
labelEncode = preprocessing.LabelEncoder()
for var in ["title", "author_1", "author_2", "publisher"]:
    df_label_encoded[var] = labelEncode.fit_transform(df_label_encoded[var])

print(df_label_encoded.shape)
df_label_encoded.head(10)
# Out:
# (11121, 18)
#    bookID  title  average_rating         isbn13 language_code  num_pages  \
# 0       1   3070            4.57  9780439785969             1        652
# 1       2   3071            4.49  9780439358071             1        870
# 2       4   3068            4.42  9780439554893             1        352
# 3       5   3073            4.56  9780439655484             1        435
# 4       8   3063            4.78  9780439682589             1       2690
# 5       9   9689            3.74  9780976540601             1        152
# 6      10   3064            4.73  9780439827607             1       3342
# 7      12   9117            4.38  9780517226957             1        815
# 8      13   9116            4.38  9780345453747             1        815
# 9      14   7796            4.22  9781400052929             1        215
#
#    ratings_count  text_reviews_count  publication_date  publisher  \
# 0        2095690               27591              6166       1777
# 1        2153167               29221              6911       1777
# 2           6333                 244              7216       1772
# 3        2339585               36325              7034       1777
# 4          41428                 164              6899       1772
# 5             19                   1              6674       1366
# 6          28242                 808              6535       1772
# 7           3628                 254              6485        788
# 8         249558                4080              7766        524
# 9           4930                 460              6940        470
#
#    num_pages_p_10  ratings_count_p_10  text_reviews_count_p_10  \
# 0               9                   9                        9
# 1               9                   9                        9
# 2               6                   7                        7
# 3               7                   9                        9
# 4               9                   9                        6
# 5               1                   0                        0
# 6               9                   9                        8
# 7               9                   7                        7
# 8               9                   9                        9
# 9               2                   7                        8
#
#    publication_year  title_len  num_authors  author_1  author_2
# 0              2006         57            2      1598      2030
# 1              2004         60            2      1598      2030
# 2              2003         58            1      1598      3236
# 3              2004         59            2      1598      2030
# 4              2004         54            2      1598      2030
# 5              2005         87            1      4064      3236
# 6              2005         44            1      1598      3236
# 7              2005        108            1       985      3236
# 8              2002         86            1       985      3236
# 9              2004         75            1       985      3236

# %% [markdown]
# So we finally ended up to 18 columns purely numeric from 12 columns initially, we will now need to make a feature selection by looking which features got more impact on our target (```average_rating```)

# %% [markdown]
# #### 2.1.8) Re-arrange columns & save pre-processed dataset

# %%
# Re-arrange and save the pre-processed dataset
rearranged_vars = [
    "average_rating",
    "bookID",
    "isbn13",
    "num_pages",
    'num_pages_p_10', 
    "ratings_count",
    'ratings_count_p_10', 
    "text_reviews_count",
    'text_reviews_count_p_10',
    "publication_date",
    "publication_year", 
    "language_code",
    "title",
    'title_len',
    "author_1", 
    "author_2",
    'num_authors',
    "publisher", 
]

df_final = df_label_encoded[rearranged_vars]
df_final.to_csv("../data/books_preprocessed.csv", index=False)
df_final.shape
# Out:
# (11121, 18)

# %% [markdown]
# ### 2.2) Feature Analysis

# %% [markdown]
# #### 2.2.1) Correlation b/w target and features from non-numeric variables

# %%
vars = [
    "average_rating", 
    "language_code",
    "title",
    'title_len',
    "author_1", 
    "author_2",
    'num_authors',
    "publisher", 
]
corr = abs(df_final[vars].corr())
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_124a8_row0_col0, #T_124a8_row1_col1, #T_124a8_row2_col2, #T_124a8_row3_col3, #T_124a8_row4_col4, #T_124a8_row5_col5, #T_124a8_row6_col6, #T_124a8_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_124a8_row0_col1, #T_124a8_row4_col2, #T_124a8_row6_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_124a8_row0_col2, #T_124a8_row0_col7, #T_124a8_row2_col3, #T_124a8_row2_col4, #T_124a8_row3_col4, #T_124a8_row7_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_124a8_row0_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_124a8_row0_col4, #T_124a8_row0_col6, #T_124a8_row4_col5, #T_124a8_row5_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_124a8_row0_col5, #T_124a8_row2_col1 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col0, #T_124a8_row5_col3, #T_124a8_row5_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col3 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col4, #T_124a8_row1_col7, #T_124a8_row2_col5, #T_124a8_row2_col6, #T_124a8_row4_col0, #T_124a8_row4_col1, #T_124a8_row5_col2, #T_124a8_row5_col7, #T_124a8_row6_col0, #T_124a8_row6_col2, #T_124a8_row6_col4, #T_124a8_row7_col1, #T_124a8_row7_col3, #T_124a8_row7_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col5, #T_124a8_row2_col7, #T_124a8_row3_col5, #T_124a8_row4_col3 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_124a8_row1_col6, #T_124a8_row2_col0, #T_124a8_row3_col7, #T_124a8_row4_col6, #T_124a8_row6_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_124a8_row3_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_124a8_row3_col1 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_124a8_row3_col2, #T_124a8_row3_col6, #T_124a8_row4_col7, #T_124a8_row5_col0, #T_124a8_row7_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_124a8_row5_col6, #T_124a8_row6_col5 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_124a8_row6_col7, #T_124a8_row7_col0, #T_124a8_row7_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_124a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_124a8_level0_col0" class="col_heading level0 col0" >average_rating</th>
#       <th id="T_124a8_level0_col1" class="col_heading level0 col1" >language_code</th>
#       <th id="T_124a8_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_124a8_level0_col3" class="col_heading level0 col3" >title_len</th>
#       <th id="T_124a8_level0_col4" class="col_heading level0 col4" >author_1</th>
#       <th id="T_124a8_level0_col5" class="col_heading level0 col5" >author_2</th>
#       <th id="T_124a8_level0_col6" class="col_heading level0 col6" >num_authors</th>
#       <th id="T_124a8_level0_col7" class="col_heading level0 col7" >publisher</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_124a8_level0_row0" class="row_heading level0 row0" >average_rating</th>
#       <td id="T_124a8_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_124a8_row0_col1" class="data row0 col1" >0.033717</td>
#       <td id="T_124a8_row0_col2" class="data row0 col2" >0.026518</td>
#       <td id="T_124a8_row0_col3" class="data row0 col3" >0.096451</td>
#       <td id="T_124a8_row0_col4" class="data row0 col4" >0.021646</td>
#       <td id="T_124a8_row0_col5" class="data row0 col5" >0.051174</td>
#       <td id="T_124a8_row0_col6" class="data row0 col6" >0.018947</td>
#       <td id="T_124a8_row0_col7" class="data row0 col7" >0.027408</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row1" class="row_heading level0 row1" >language_code</th>
#       <td id="T_124a8_row1_col0" class="data row1 col0" >0.033717</td>
#       <td id="T_124a8_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_124a8_row1_col2" class="data row1 col2" >0.052061</td>
#       <td id="T_124a8_row1_col3" class="data row1 col3" >0.069927</td>
#       <td id="T_124a8_row1_col4" class="data row1 col4" >0.004082</td>
#       <td id="T_124a8_row1_col5" class="data row1 col5" >0.021827</td>
#       <td id="T_124a8_row1_col6" class="data row1 col6" >0.009668</td>
#       <td id="T_124a8_row1_col7" class="data row1 col7" >0.002911</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row2" class="row_heading level0 row2" >title</th>
#       <td id="T_124a8_row2_col0" class="data row2 col0" >0.026518</td>
#       <td id="T_124a8_row2_col1" class="data row2 col1" >0.052061</td>
#       <td id="T_124a8_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_124a8_row2_col3" class="data row2 col3" >0.032312</td>
#       <td id="T_124a8_row2_col4" class="data row2 col4" >0.029074</td>
#       <td id="T_124a8_row2_col5" class="data row2 col5" >0.000708</td>
#       <td id="T_124a8_row2_col6" class="data row2 col6" >0.002161</td>
#       <td id="T_124a8_row2_col7" class="data row2 col7" >0.024765</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row3" class="row_heading level0 row3" >title_len</th>
#       <td id="T_124a8_row3_col0" class="data row3 col0" >0.096451</td>
#       <td id="T_124a8_row3_col1" class="data row3 col1" >0.069927</td>
#       <td id="T_124a8_row3_col2" class="data row3 col2" >0.032312</td>
#       <td id="T_124a8_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_124a8_row3_col4" class="data row3 col4" >0.027891</td>
#       <td id="T_124a8_row3_col5" class="data row3 col5" >0.022055</td>
#       <td id="T_124a8_row3_col6" class="data row3 col6" >0.036263</td>
#       <td id="T_124a8_row3_col7" class="data row3 col7" >0.007670</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row4" class="row_heading level0 row4" >author_1</th>
#       <td id="T_124a8_row4_col0" class="data row4 col0" >0.021646</td>
#       <td id="T_124a8_row4_col1" class="data row4 col1" >0.004082</td>
#       <td id="T_124a8_row4_col2" class="data row4 col2" >0.029074</td>
#       <td id="T_124a8_row4_col3" class="data row4 col3" >0.027891</td>
#       <td id="T_124a8_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_124a8_row4_col5" class="data row4 col5" >0.016950</td>
#       <td id="T_124a8_row4_col6" class="data row4 col6" >0.006355</td>
#       <td id="T_124a8_row4_col7" class="data row4 col7" >0.036655</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row5" class="row_heading level0 row5" >author_2</th>
#       <td id="T_124a8_row5_col0" class="data row5 col0" >0.051174</td>
#       <td id="T_124a8_row5_col1" class="data row5 col1" >0.021827</td>
#       <td id="T_124a8_row5_col2" class="data row5 col2" >0.000708</td>
#       <td id="T_124a8_row5_col3" class="data row5 col3" >0.022055</td>
#       <td id="T_124a8_row5_col4" class="data row5 col4" >0.016950</td>
#       <td id="T_124a8_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_124a8_row5_col6" class="data row5 col6" >0.385501</td>
#       <td id="T_124a8_row5_col7" class="data row5 col7" >0.001582</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row6" class="row_heading level0 row6" >num_authors</th>
#       <td id="T_124a8_row6_col0" class="data row6 col0" >0.018947</td>
#       <td id="T_124a8_row6_col1" class="data row6 col1" >0.009668</td>
#       <td id="T_124a8_row6_col2" class="data row6 col2" >0.002161</td>
#       <td id="T_124a8_row6_col3" class="data row6 col3" >0.036263</td>
#       <td id="T_124a8_row6_col4" class="data row6 col4" >0.006355</td>
#       <td id="T_124a8_row6_col5" class="data row6 col5" >0.385501</td>
#       <td id="T_124a8_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_124a8_row6_col7" class="data row6 col7" >0.010010</td>
#     </tr>
#     <tr>
#       <th id="T_124a8_level0_row7" class="row_heading level0 row7" >publisher</th>
#       <td id="T_124a8_row7_col0" class="data row7 col0" >0.027408</td>
#       <td id="T_124a8_row7_col1" class="data row7 col1" >0.002911</td>
#       <td id="T_124a8_row7_col2" class="data row7 col2" >0.024765</td>
#       <td id="T_124a8_row7_col3" class="data row7 col

# %%
# Absolute correlation b/w target and features
corr2 = pd.DataFrame(corr.iloc[1:-1, 0])
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_85d75_row0_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_85d75_row1_col0 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_85d75_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_85d75_row3_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_85d75_row4_col0 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_85d75_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_85d75">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85d75_level0_col0" class="col_heading level0 col0" >average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85d75_level0_row0" class="row_heading level0 row0" >language_code</th>
#       <td id="T_85d75_row0_col0" class="data row0 col0" >0.033717</td>
#     </tr>
#     <tr>
#       <th id="T_85d75_level0_row1" class="row_heading level0 row1" >title</th>
#       <td id="T_85d75_row1_col0" class="data row1 col0" >0.026518</td>
#     </tr>
#     <tr>
#       <th id="T_85d75_level0_row2" class="row_heading level0 row2" >title_len</th>
#       <td id="T_85d75_row2_col0" class="data row2 col0" >0.096451</td>
#     </tr>
#     <tr>
#       <th id="T_85d75_level0_row3" class="row_heading level0 row3" >author_1</th>
#       <td id="T_85d75_row3_col0" class="data row3 col0" >0.021646</td>
#     </tr>
#     <tr>
#       <th id="T_85d75_level0_row4" class="row_heading level0 row4" >author_2</th>
#       <td id="T_85d75_row4_col0" class="data row4 col0" >0.051174</td>
#     </tr>
#     <tr>
#       <th id="T_85d75_level0_row5" class="row_heading level0 row5" >num_authors</th>
#       <td id="T_85d75_row5_col0" class="data row5 col0" >0.018947</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We see very low correlation b/w the features and the target, however we found a slightly higher correlation b/w the target and our "engineered" features like ```title_len``` compared to ```title```. However the engineered feature ```num_authors``` has the lowest correlation.

# %% [markdown]
# #### 2.2.2) Correlation b/w target and features from numeric variables

# %%
vars = [
    "average_rating",
    "bookID",
    "isbn13",
    "num_pages",
    'num_pages_p_10', 
    "ratings_count",
    'ratings_count_p_10', 
    "text_reviews_count",
    'text_reviews_count_p_10',
    "publication_date",
    "publication_year", 
]
corr = abs(df_final[vars].corr())
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c9238_row0_col0, #T_c9238_row1_col1, #T_c9238_row2_col2, #T_c9238_row3_col3, #T_c9238_row4_col4, #T_c9238_row5_col5, #T_c9238_row6_col6, #T_c9238_row7_col7, #T_c9238_row8_col8, #T_c9238_row9_col9, #T_c9238_row9_col10, #T_c9238_row10_col9, #T_c9238_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col1, #T_c9238_row0_col5, #T_c9238_row0_col10, #T_c9238_row1_col0, #T_c9238_row6_col2, #T_c9238_row7_col0, #T_c9238_row8_col2 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col2, #T_c9238_row1_col2, #T_c9238_row2_col0, #T_c9238_row2_col1, #T_c9238_row2_col3, #T_c9238_row2_col4, #T_c9238_row2_col5, #T_c9238_row2_col6, #T_c9238_row2_col7, #T_c9238_row2_col8, #T_c9238_row2_col9, #T_c9238_row2_col10, #T_c9238_row4_col9, #T_c9238_row4_col10, #T_c9238_row9_col2, #T_c9238_row9_col4, #T_c9238_row10_col2, #T_c9238_row10_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col4 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col6 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col7, #T_c9238_row1_col9, #T_c9238_row3_col1, #T_c9238_row5_col3, #T_c9238_row9_col1, #T_c9238_row10_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col8, #T_c9238_row5_col0, #T_c9238_row9_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c9238_row0_col9, #T_c9238_row1_col10, #T_c9238_row3_col5, #T_c9238_row3_col7, #T_c9238_row7_col3, #T_c9238_row9_col0, #T_c9238_row10_col0 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c9238_row1_col3, #T_c9238_row3_col9, #T_c9238_row3_col10 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c9238_row1_col4, #T_c9238_row4_col1, #T_c9238_row4_col2, #T_c9238_row5_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c9238_row1_col5, #T_c9238_row1_col7, #T_c9238_row3_col8 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_c9238_row1_col6, #T_c9238_row7_col10, #T_c9238_row8_col0 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c9238_row1_col8, #T_c9238_row5_col1 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_c9238_row3_col0, #T_c9238_row4_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_c9238_row3_col2, #T_c9238_row7_col2, #T_c9238_row9_col3, #T_c9238_row10_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c9238_row3_col4 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_c9238_row3_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c9238_row4_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c9238_row4_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_c9238_row4_col5, #T_c9238_row5_col4, #T_c9238_row5_col9, #T_c9238_row5_col10 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c9238_row4_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c9238_row4_col8 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c9238_row5_col6 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c9238_row5_col7, #T_c9238_row7_col5 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c9238_row5_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col0, #T_c9238_row6_col3 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col1, #T_c9238_row8_col3, #T_c9238_row9_col6, #T_c9238_row10_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col5 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col7 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_c9238_row6_col8, #T_c9238_row8_col6 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c9238_row6_col10 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c9238_row7_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c9238_row7_col4, #T_c9238_row9_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_c9238_row7_col6 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_c9238_row7_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_c9238_row7_col9 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_c9238_row8_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c9238_row8_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c9238_row8_col5 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_c9238_row8_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_c9238_row8_col9, #T_c9238_row8_col10 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c9238_row9_col8, #T_c9238_row10_col8 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c9238_row10_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c9238_row10_col7 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c9238">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9238_level0_col0" class="col_heading level0 col0" >average_rating</th>
#       <th id="T_c9238_level0_col1" class="col_heading level0 col1" >bookID</th>
#       <th id="T_c9238_level0_col2" class="col_heading level0 col2" >isbn13</th>
#       <th id="T_c9238_level0_col3" class="col_heading level0 col3" >num_pages</th>
#       <th id="T_c9238_level0_col4" class="col_heading level0 col4" >num_pages_p_10</th>
#       <th id="T_c9238_level0_col5" class="col_heading level0 col5" >ratings_count</th>
#       <th id="T_c9238_level0_col6" class="col_heading level0 col6" >ratings_count_p_10</th>
#       <th id="T_c9238_level0_col7" class="col_heading level0 col7" >text_reviews_count</th>
#       <th id="T_c9238_level0_col8" class="col_heading level0 col8" >text_reviews_count_p_10</th>
#       <th id="T_c9238_level0_col9" class="col_heading level0 col9" >publication_date</th>
#       <th id="T_c9238_level0_col10" class="col_heading level0 col10" >publication_year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9238_level0_row0" class="row_heading level0 row0" >average_rating</th>
#       <td id="T_c9238_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c9238_row0_col1" class="data row0 col1" >0.036259</td>
#       <td id="T_c9238_row0_col2" class="data row0 col2" >0.001967</td>
#       <td id="T_c9238_row0_col3" class="data row0 col3" >0.150430</td>
#       <td id="T_c9238_row0_col4" class="data row0 col4" >0.103904</td>
#       <td id="T_c9238_row0_col5" class="data row0 col5" >0.038228</td>
#       <td id="T_c9238_row0_col6" class="data row0 col6" >0.115798</td>
#       <td id="T_c9238_row0_col7" class="data row0 col7" >0.033669</td>
#       <td id="T_c9238_row0_col8" class="data row0 col8" >0.069308</td>
#       <td id="T_c9238_row0_col9" class="data row0 col9" >0.030897</td>
#       <td id="T_c9238_row0_col10" class="data row0 col10" >0.031730</td>
#     </tr>
#     <tr>
#       <th id="T_c9238_level0_row1" class="row_heading level0 row1" >bookID</th>
#       <td id="T_c9238_row1_col0" class="data row1 col0" >0.036259</td>
#       <td id="T_c9238_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c9238_row1_col2" class="data row1 col2" >0.002197</td>
#       <td id="T_c9238_row1_col3" class="data row1 col3" >0.026463</td>
#       <td id="T_c9238_row1_col4" class="data row1 col4" >0.009094</td>
#       <td id="T_c9238_row1_col5" class="data row1 col5" >0.076803</td>
#       <td id="T_c9238_row1_col6" class="data row1 col6" >0.097595</td>
#       <td id="T_c9238_row1_col7" class="data row1 col7" >0.081262</td>
#       <td id="T_c9238_row1_col8" class="data row1 col8" >0.107525</td>
#       <td id="T_c9238_row1_col9" class="data row1 col9" >0.027796</td>
#       <td id="T_c9238_row1_col10" class="data row1 col10" >0.027861</td>
#     </tr>
#     <tr>
#       <th id="T_c9238_level0_row2" class="row_heading level0 row2" >isbn13</th>
#       <td id="T_c9238_row2_col0" class="data row2 col0" >0.001967</td>
#       <td id="T_c9238_row2_col1" class="data row2 col1" >0.002197</td>
#       <td id="T_c9238_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c

# %%
# Absolute correlation b/w target and features
corr2 = pd.DataFrame(corr.iloc[1:-1, 0])
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b4286_row0_col0 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b4286_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b4286_row2_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b4286_row3_col0 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_b4286_row4_col0 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_b4286_row5_col0 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_b4286_row6_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b4286_row7_col0 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_b4286_row8_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b4286">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4286_level0_col0" class="col_heading level0 col0" >average_rating</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4286_level0_row0" class="row_heading level0 row0" >bookID</th>
#       <td id="T_b4286_row0_col0" class="data row0 col0" >0.036259</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row1" class="row_heading level0 row1" >isbn13</th>
#       <td id="T_b4286_row1_col0" class="data row1 col0" >0.001967</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row2" class="row_heading level0 row2" >num_pages</th>
#       <td id="T_b4286_row2_col0" class="data row2 col0" >0.150430</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row3" class="row_heading level0 row3" >num_pages_p_10</th>
#       <td id="T_b4286_row3_col0" class="data row3 col0" >0.103904</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row4" class="row_heading level0 row4" >ratings_count</th>
#       <td id="T_b4286_row4_col0" class="data row4 col0" >0.038228</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row5" class="row_heading level0 row5" >ratings_count_p_10</th>
#       <td id="T_b4286_row5_col0" class="data row5 col0" >0.115798</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row6" class="row_heading level0 row6" >text_reviews_count</th>
#       <td id="T_b4286_row6_col0" class="data row6 col0" >0.033669</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row7" class="row_heading level0 row7" >text_reviews_count_p_10</th>
#       <td id="T_b4286_row7_col0" class="data row7 col0" >0.069308</td>
#     </tr>
#     <tr>
#       <th id="T_b4286_level0_row8" class="row_heading level0 row8" >publication_date</th>
#       <td id="T_b4286_row8_col0" class="data row8 col0" >0.030897</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We have slightly higher correlations for numeric features and we can see that our Quantile Regrouping on some features was efficient.
# For the ```ratings_count``` and ```text_reviews_count```, we get higher correlations with their corresponding "engineered" features which will probably help our model to perform better, but not for the ```num_pages``` column.
#
# We can see also that the ```publication_year``` has a slightly higher correlation with the target than the ```publication_date```. But by keeping only the year, we loose some information which maybe useful to train the model, hence we cannot really know which one to keep and we will find out experimentally in the next section.
#
# For the unique identifiers, surprisingly, the ```bookID``` seems to have some correlation to the target, however it does not make sense to keep the ```isbn13``` column due to its very low correlation with the target.

# %% [markdown]
# **Synthesis**:
# - We will drop both the ```isbn13``` for the above reasons.
# - However, due to the generally low correlation of the features with the target, we cannot know which features to select, as for some of the "engineered" features, we have gain in correlation but we have lost some information, hence we do not know how the models will interpret these features. Therefore, we will find **experimentally** the best set of features in the next section by evaluatin with the models.
